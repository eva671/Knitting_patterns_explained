# %%
# Get useful packages

import sys

# Check Jupyter kernal path (when this differs from the output of `!type Python`, package may not be found.)
# See: https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/ for details.
sys.executable

# install required packages (%pip install is the same as !/opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/bin/python3.11 -m pip install)
# %pip install PyPDF2

# importing required modules
import PyPDF2
from PyPDF2 import PdfReader
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/3.6.1/libexec/bin/python3.11 -m pip install --upgrade pip

# %%
# Read the PDF file (from: https://www.dontbesuchasquare.com/free-printables-2/#charts)
reader = PdfReader("KnittingAbbreviations.pdf")

page = reader.pages[0]

dic_list = page.extract_text()

print(dic_list)
# Out:
# alt alternate
# approx approximately
# beg beginning
# bet between
# bo bind off / cast off
# byo backward yarn over
# cable put as many stitches as your pattern say on a cable
# needle and place it in front or back depending on
# the pattern. Work the next set of stitches and then
# work stitches off the cable needle.
# CC contrasting color
# ch chain
# cm centimeter
# cn cable needle
# CO cast on
# con continue
# cross put as many stitches as your pattern say on a cable
# needle and place it in front or back depending on
# the pattern. Work the next set of stitches and then
# work stitches off the cable needle.
# dec decrease
# dpn double pointed needles
# foll follow
# g gram
# g st garter stitch
# in inches
# inc increase
# incl including
# k knit
# k1B knit 1 stitch in row below
# kfb knit front and back loop
# ksp knit 1 stitch, slip st from right to left needle, pass
# second stitch on left needle over first stitch and off
# ...
